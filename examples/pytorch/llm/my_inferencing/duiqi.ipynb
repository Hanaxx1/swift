# %%
#欢迎帅哥
#开发时间: 2024-02-01 13:08

def get_characters_before_third_comma(input_string):
    count_comma = 0
    index_third_comma = None

    for i, char in enumerate(input_string):
        if char == ',':
            count_comma += 1
            if count_comma == 3:
                index_third_comma = i
                break

    if index_third_comma is not None:
        return input_string[:index_third_comma]
    else:
        return "Third comma not found"

import json
import matplotlib.pyplot as plt
import linecache

# 定义三个列表存储数据
llama_list = []
mistral_list = []
openchat_list = []


with open('/home/qiuyang/workplace/swift/examples/pytorch/llm/my_data/data_siyuanzu/mistral_list11_vllm.json', 'r') as file:
    data_mistral = json.load(file)
with open('/home/qiuyang/workplace/swift/examples/pytorch/llm/my_data/data_siyuanzu/openchat_list11_vllm.json', 'r') as file:
    data_openchat = json.load(file)
with open('/home/qiuyang/workplace/swift/examples/pytorch/llm/my_data/data_siyuanzu/solar_list11_vllm.json', 'r') as file:
    data_solar = json.load(file)


path_file = '/home/qiuyang/workplace/swift/examples/pytorch/llm/my_data/data/c4_data_length_3500/c4_data11_3500.json'



# 打印列表长度以验证数据加载情况
print("mistral_list length:", len(data_mistral))
print("openchat_list length:", len(data_openchat))
print("solar_list length:",len(data_solar))

count = 0

with open('/home/qiuyang/workplace/swift/examples/pytorch/llm/my_data/data/c4_data_duiqi/c4_data_dongtai.json', 'a') as output_file:
    for i in range(0,len(data_mistral)):
        # print(i)
        if data_mistral[i] == data_openchat[i] and data_mistral[i]!="[No,UNKNOWN,UNKNOWN,UNKNOWN]" and data_mistral[i] == data_solar[i]:
            count = count + 1
            # 指定要读取的行数
            line_number = i+1
            # 使用 linecache 模块读取指定行数的内容
            line = linecache.getline(path_file, line_number)
            # 解析JSON数据
            data = json.loads(line.strip())  # strip() 方法用于删除行尾的换行符
            origin = str(data_mistral[i]).split(',')[1]
            destination = str(data_mistral[i]).split(',')[2]
            timestamp = str(data_mistral[i]).split(',')[3].split(']')[0]
            # print(data_mistral[i],origin,destination,timestamp)
            data['origin'] = origin
            data['destination'] = destination
            data['timestamp'] = timestamp

            #写入
            json.dump(data, output_file)
            output_file.write('\n')

print("result_one consistent results:",count)
print('-------------------')
# Out:
# mistral_list length: 8527
# openchat_list length: 8527
# solar_list length: 8527
# result_one consistent results: 1403
# -------------------

# %%
import json
import matplotlib.pyplot as plt
import linecache
with open('/home/qiuyang/workplace/swift/examples/pytorch/llm/my_data/data_siyuanzu/mistral_list_allnews14.json', 'r') as file:
    data_mistral = json.load(file)
with open('/home/qiuyang/workplace/swift/examples/pytorch/llm/my_data/data_siyuanzu/openchat_list_allnews14.json', 'r') as file:
    data_openchat = json.load(file)
with open('/home/qiuyang/workplace/swift/examples/pytorch/llm/my_data/data_siyuanzu/solar_list_allnews14.json', 'r') as file:
    data_solar = json.load(file)
print(len(data_mistral))
print(len(data_openchat))

count = 0
for i in range(0,len(data_mistral)):
        # print(i)
        if data_mistral[i] == data_openchat[i] and data_mistral[i]!="[No,UNKNOWN,UNKNOWN,UNKNOWN]" and data_mistral[i] == data_solar[i]:
            
            count = count + 1
        else:
             pass
print(count)

count_san = 0

for i in range(9,len(data_mistral)):
        result_mistral = data_mistral[i][:-8]
        result_openchat = data_openchat[i][:-8]
        result_solar = data_solar[i][:-8]
        if result_mistral != '[No,UNKNOWN,UNKNOWN,' and result_mistral == result_openchat and result_mistral == result_solar:
             count_san = count_san + 1

print(count_san)

# with open('/home/qiuyang/workplace/swift/examples/pytorch/llm/my_data/data/c4_data_length_3500/c4_data11_3500.json', 'r') as input_file:
#     path_file = '/home/qiuyang/workplace/swift/examples/pytorch/llm/my_data/data/c4_data_jingtai/c4_data11_3500_jingtai.json'
#     i = 0
#     with open(path_file, 'w') as output_file:
#         # 逐行读取文件内容
#         for line in input_file:
#             # 解析JSON数据
#             data = json.loads(line)
#             if data_mistral[i] == data_openchat[i] and data_mistral[i]!="[No,UNKNOWN,UNKNOWN,UNKNOWN]" and data_mistral[i] == data_solar[i]:
#                 # 写入符合条件的数据到目标文件中
#                 pass
#             else:
#                 json.dump(data, output_file)
#                 output_file.write('\n')
#             i = i + 1
# Out:
# 88025
# 88025
# 7999
# 10024

# %%
import json
import matplotlib.pyplot as plt
import linecache

with open('/home/qiuyang/workplace/swift/examples/pytorch/llm/my_data/data_sanyuanzu/mistral_list11_jingtai.json', 'r') as file:
    data_mistral = json.load(file)
with open('/home/qiuyang/workplace/swift/examples/pytorch/llm/my_data/data_sanyuanzu/openchat_list11_jingtai.json', 'r') as file:
    data_openchat = json.load(file)
with open('/home/qiuyang/workplace/swift/examples/pytorch/llm/my_data/data_sanyuanzu/solar_list11_jingtai.json', 'r') as file:
    data_solar = json.load(file)

count = 0
print(len(data_mistral))
# for i in range(0,len(data_mistral)):
#         # print(i)
#         if data_mistral[i] == data_openchat[i] and data_mistral[i]!="[No,UNKNOWN,UNKNOWN]" and data_mistral[i] == data_solar[i]:
            
#             count = count + 1
#         else:
#              pass
# print(count)

path_file = '/home/qiuyang/workplace/swift/examples/pytorch/llm/my_data/data/c4_data_length_3500/c4_data11_3500.json'


with open('/home/qiuyang/workplace/swift/examples/pytorch/llm/my_data/data/c4_data_duiqi/c4_data_jingtai.json', 'a') as output_file:
    for i in range(0,len(data_mistral)):
        # print(i)
        if data_mistral[i] == data_openchat[i] and data_mistral[i]!="[No,UNKNOWN,UNKNOWN]" and data_mistral[i] == data_solar[i]:
            count = count + 1
            # 指定要读取的行数
            line_number = i+1
            # 使用 linecache 模块读取指定行数的内容
            line = linecache.getline(path_file, line_number)
            # 解析JSON数据
            data = json.loads(line.strip())  # strip() 方法用于删除行尾的换行符
            origin = str(data_mistral[i]).split(',')[1]
            destination = str(data_mistral[i]).split(',')[2].split(']')[0]
            # timestamp = str(data_mistral[i]).split(',')[3].split(']')[0]
            # print(data_mistral[i],origin,destination,timestamp)
            data['origin'] = origin
            data['destination'] = destination
            data['timestamp'] = 'UNKNOWN'
            # print(origin)
            # print(destination)
            # break

            #写入
            json.dump(data, output_file)
            output_file.write('\n')

print("result_one consistent results:",count)
print('-------------------')
# Out:
# 7124
# result_one consistent results: 1675
# -------------------
